# %%
import mosqlient as mosq

# %%
import os
from dotenv import load_dotenv

# Access the environment variables
api_key = os.getenv('api_key')

# %%
ids_to_del = [12060, 12069, 12071, 12072, 12073, 12074, 12075, 12076, 12077,
       12079, 12081, 12082, 12098, 12099, 12100, 12101, 12102, 12103,
       12104, 12105, 12106, 12107, 12108, 12109, 12110, 12112, 12113,
       12114, 12115, 12116, 12117, 12118, 12119, 12120, 12121, 12122,
       12123, 12124, 12125, 12127]

len(ids_to_del)
# Out:
# 40

# %%
for id_ in ids_to_del: 
    
    mosq.delete_prediction(
                api_key= api_key,
                prediction_id = id_)
