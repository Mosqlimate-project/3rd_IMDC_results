# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
label = 'dengue_city'

caminho_da_pasta = Path("./predictions/")

padrao_arquivo = f"{label}_*.csv.gz"  # Altere para o seu termo

arquivos_encontrados = list(caminho_da_pasta.glob(padrao_arquivo))

arquivos_encontrados
# Out:
# [PosixPath('predictions/dengue_city_3rd_imdc_isi_isi-dengue.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_fgv_pattern-blue.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_emap_lstm_muni.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_purdue_neuralearth.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_emap_epidematicos_prophet.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_nus_nus-cerm.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_universidad_del_valle_grupo_modelamiento_datos_dengue.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_emap_xgbsillas.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_emap_epidematicos_sarimax_muni.csv.gz'),
#  PosixPath('predictions/dengue_city_3rd_imdc_unesp_recogna.csv.gz')]

# %%
list_dfs = []

for arq in arquivos_encontrados:

    df_ = pd.read_csv(arq)
    df_['model'] = str(arq)[24:-7]

    list_dfs.append(df_)


df_end = pd.concat(list_dfs, ignore_index = True)

df_end.to_csv(f'./predictions/predictions_all_models_{label}.csv.gz')


df_end.head()
# Out:
#          date  lower_95  lower_90  lower_80  lower_50       pred   upper_50  \
# 0  2022-10-09  5.000000  5.000000  5.000000  5.000000   5.000000   5.000000
# 1  2022-10-16  7.624455  8.057647  8.563331  9.403538  10.336016  11.416484
# 2  2022-10-23  0.002200  0.019268  0.094842  0.246298   0.516110   1.013062
# 3  2022-10-30  0.008068  0.008721  0.009537  0.011092   0.013063   0.015955
# 4  2022-11-06  0.206284  0.211000  0.216696  0.225576   0.237373   0.250423
#
#     upper_80   upper_90   upper_95    adm_2    id  validation    wis  \
# 0   5.000000   5.000000   5.000000  2931350  7890           1  19.57
# 1  12.340992  12.851863  13.190387  2931350  7890           1  19.57
# 2   1.639324   2.108751   2.516792  2931350  7890           1  19.57
# 3   0.020393   0.024022   0.032237  2931350  7890           1  19.57
# 4   0.263142   0.271593   0.286299  2931350  7890           1  19.57
#
#                      model
# 0  3rd_imdc_isi_isi-dengue
# 1  3rd_imdc_isi_isi-dengue
# 2  3rd_imdc_isi_isi-dengue
# 3  3rd_imdc_isi_isi-dengue
# 4  3rd_imdc_isi_isi-dengue

# %%
df_end.model.unique().shape
# Out:
# (10,)

# %%
df_end.model.unique()
# Out:
# <ArrowStringArray>
# [                                       'rd_imdc_isi_isi-dengue',
#                                       'rd_imdc_fgv_pattern-blue',
#                                         'rd_imdc_emap_lstm_muni',
#                                     'rd_imdc_purdue_neuralearth',
#                              'rd_imdc_emap_epidematicos_prophet',
#                                           'rd_imdc_nus_nus-cerm',
#  'rd_imdc_universidad_del_valle_grupo_modelamiento_datos_dengue',
#                                         'rd_imdc_emap_xgbsillas',
#                         'rd_imdc_emap_epidematicos_sarimax_muni',
#                                          'rd_imdc_unesp_recogna']
# Length: 10, dtype: str
