# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
label = 'chik_city'

caminho_da_pasta = Path("./predictions/")

padrao_arquivo = f"{label}_*.csv.gz"  # Altere para o seu termo

arquivos_encontrados = list(caminho_da_pasta.glob(padrao_arquivo))

arquivos_encontrados
# Out:
# [PosixPath('predictions/chik_city_3rd_imdc_emap_epidematicos_prophet.csv.gz'),
#  PosixPath('predictions/chik_city_3rd_imdc_nus_nus-cerm.csv.gz'),
#  PosixPath('predictions/chik_city_3rd_imdc_emap_epidematicos_sarimax_muni.csv.gz'),
#  PosixPath('predictions/chik_city_3rd_imdc_emap_lstm_muni.csv.gz'),
#  PosixPath('predictions/chik_city_3rd_imdc_emap_xgbsillas.csv.gz'),
#  PosixPath('predictions/chik_city_3rd_imdc_purdue_neuralearth.csv.gz')]

# %%
list_dfs = []

for arq in arquivos_encontrados:

    df_ = pd.read_csv(arq)
    df_['model'] = str(arq)[22:-7]

    list_dfs.append(df_)


df_end = pd.concat(list_dfs, ignore_index = True)

df_end.to_csv(f'./predictions/predictions_all_models_{label}.csv.gz')


df_end.head()
# Out:
#          date  lower_95  lower_90  lower_80  lower_50      pred  upper_50  \
# 0  2022-10-09  0.055665  0.212458  0.433722  1.040944  2.078688  5.014152
# 1  2022-10-16  0.129924  0.150721  0.512863  0.789217  1.698967  4.608482
# 2  2022-10-23  0.167603  0.189093  0.322311  1.077777  2.078474  4.075722
# 3  2022-10-30  0.000000  0.000000  0.049948  0.593776  1.713534  3.896104
# 4  2022-11-06  0.000000  0.000000  0.000000  0.345545  1.215062  3.177605
#
#    upper_80   upper_90   upper_95    adm_2    id  validation        wis  \
# 0  8.274178  13.705758  19.956902  2211001  8515           1  18.427146
# 1  6.717145   8.018087  11.891967  2211001  8515           1  18.427146
# 2  6.833111   7.773644   8.318806  2211001  8515           1  18.427146
# 3  5.676596   6.242217  10.483744  2211001  8515           1  18.427146
# 4  4.522743   5.318249   8.392595  2211001  8515           1  18.427146
#
#                                 model
# 0  3rd_imdc_emap_epidematicos_prophet
# 1  3rd_imdc_emap_epidematicos_prophet
# 2  3rd_imdc_emap_epidematicos_prophet
# 3  3rd_imdc_emap_epidematicos_prophet
# 4  3rd_imdc_emap_epidematicos_prophet

# %%
df_end.model.unique().shape
# Out:
# (6,)

# %%
df_end.model.unique()
# Out:
# <ArrowStringArray>
# [     '3rd_imdc_emap_epidematicos_prophet',
#                    '3rd_imdc_nus_nus-cerm',
#  '3rd_imdc_emap_epidematicos_sarimax_muni',
#                  '3rd_imdc_emap_lstm_muni',
#                  '3rd_imdc_emap_xgbsillas',
#              '3rd_imdc_purdue_neuralearth']
# Length: 6, dtype: str
