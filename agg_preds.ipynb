# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
label = 'dengue_state'

caminho_da_pasta = Path("./predictions/")

padrao_arquivo = f"{label}_*.csv.gz"  # Altere para o seu termo

arquivos_encontrados = list(caminho_da_pasta.glob(padrao_arquivo))

arquivos_encontrados
# Out:
# [PosixPath('predictions/dengue_state_3rd_imdc_isi_isi-dengue.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_purdue_neuralearth.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_fiocruz_mard.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_bsc_ghr.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_fgv_pattern-blue.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_lncc_lncc_arp26_dengue.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_procc_bb_model.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_unesp_recogna.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_ifgw_inframind-proteus.csv.gz'),
#  PosixPath('predictions/dengue_state_DS-OKSTATE-2026.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_ceri_returnoftheforecast.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_nus_nus-cerm.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_lncc_surge_model26_dengue.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_pucrio_arbocaster.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_emap_lstm.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_emap_xgbsillas.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_-unifesp-_-4mosqueteiras-.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_universidad_del_valle_grupo_modelamiento_datos_dengue.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_lncc_clidengo26dengue.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_fiocruz_zerolags.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_cornell_bentolab.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_emap_epidematicos_prophet.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_fgv_sakhal.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_rki_rki_zki_ph_lstm_geo.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_afya_ric.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_rki_rki_zki_ph.csv.gz'),
#  PosixPath('predictions/dengue_state_3rd_imdc_emap_epidematicos_sarimax_state.csv.gz')]

# %%
arq = 'predictions/chik_state_3rd_imdc_emap_lstm.csv.gz'

str(arq)[23:-7]
# Out:
# '3rd_imdc_emap_lstm'

# %%
list_dfs = []

for arq in arquivos_encontrados:

    df_ = pd.read_csv(arq)
    df_['model'] = str(arq)[25:-7]

    list_dfs.append(df_)


df_end = pd.concat(list_dfs, ignore_index = True)

df_end.to_csv(f'./predictions/predictions_all_models_{label}.csv.gz')


df_end.head()
# Out:
#          date   lower_95   lower_90   lower_80    lower_50        pred  \
# 0  2022-10-09  13.000000  13.000000  13.000000   13.000000   13.000000
# 1  2022-10-16  37.019327  43.295517  51.743385   66.653189   83.207109
# 2  2022-10-23  55.945220  68.411390  84.200302  108.887826  135.698419
# 3  2022-10-30  58.185781  69.697014  83.792687  107.076328  132.601767
# 4  2022-11-06  58.634062  68.591352  80.855678  101.969117  125.548661
#
#      upper_50    upper_80    upper_90    upper_95  adm_1    id  validation  \
# 0   13.000000   13.000000   13.000000   13.000000     12  6822           1
# 1  100.790847  116.992117  126.864602  134.406880     12  6822           1
# 2  163.344639  189.017119  205.765306  218.575663     12  6822           1
# 3  158.745145  184.276095  201.204977  212.912726     12  6822           1
# 4  150.259612  174.517426  190.524410  202.512661     12  6822           1
#
#      wis                    model
# 0  95.67  3rd_imdc_isi_isi-dengue
# 1  95.67  3rd_imdc_isi_isi-dengue
# 2  95.67  3rd_imdc_isi_isi-dengue
# 3  95.67  3rd_imdc_isi_isi-dengue
# 4  95.67  3rd_imdc_isi_isi-dengue

# %%
df_end.model.unique().shape
# Out:
# (27,)

# %%
df_end.model.unique()
# Out:
# <ArrowStringArray>
# [                                       '3rd_imdc_isi_isi-dengue',
#                                     '3rd_imdc_purdue_neuralearth',
#                                           '3rd_imdc_fiocruz_mard',
#                                                '3rd_imdc_bsc_ghr',
#                                       '3rd_imdc_fgv_pattern-blue',
#                                 '3rd_imdc_lncc_lncc_arp26_dengue',
#                                         '3rd_imdc_procc_bb_model',
#                                          '3rd_imdc_unesp_recogna',
#                                 '3rd_imdc_ifgw_inframind-proteus',
#                                                 'DS-OKSTATE-2026',
#                               '3rd_imdc_ceri_returnoftheforecast',
#                                           '3rd_imdc_nus_nus-cerm',
#                              '3rd_imdc_lncc_surge_model26_dengue',
#                                      '3rd_imdc_pucrio_arbocaster',
#                                              '3rd_imdc_emap_lstm',
#                                         '3rd_imdc_emap_xgbsillas',
#                              '3rd_imdc_-unifesp-_-4mosqueteiras-',
#  '3rd_imdc_universidad_del_valle_grupo_modelamiento_datos_dengue',
#                                  '3rd_imdc_lncc_clidengo26dengue',
#                                       '3rd_imdc_fiocruz_zerolags',
#                                       '3rd_imdc_cornell_bentolab',
#                              '3rd_imdc_emap_epidematicos_prophet',
#                                             '3rd_imdc_fgv_sakhal',
#                                '3rd_imdc_rki_rki_zki_ph_lstm_geo',
#                                               '3rd_imdc_afya_ric',
#                                         '3rd_imdc_rki_rki_zki_ph',
#                        '3rd_imdc_emap_epidematicos_sarimax_state']
# Length: 27, dtype: str
